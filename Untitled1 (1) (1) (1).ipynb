# %% [markdown]
# In the following analysis, we will take a look at impression delivery, CTR, margin% and potentially other metrics over time for the following direct team accounts:
#
# Skechers Rack Room Shoes Britvic Chico's David Yurman OOFOS Roberto Coin Zebco Fishing

# %% [markdown]
# to do: what is the trend for different KPIs? (impressions, CTR, etc) what is the seasonlaity? what are the peaks? what is the forecast? correlations? outliers? treating outliers month over month performance?

# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os 

# %matplotlib inline

# %%
df = pd.read_csv("Direct Seasonality Consolidated.csv")

# %%
#Checking first 5 rows
df
# Out:
#               Day      Advertiser            Tactic  \
# 0        8/3/2017        Skechers               NaN
# 1        8/3/2017        Skechers               NaN
# 2        8/3/2017        Skechers               NaN
# 3        8/3/2017        Skechers               NaN
# 4        8/4/2017        Skechers           PreRoll
# 5        8/4/2017        Skechers               NaN
# 6        8/4/2017        Skechers      Amazon Video
# 7        8/4/2017        Skechers  YouTube TrueView
# 8        8/4/2017        Skechers               NaN
# 9        8/4/2017        Skechers               NaN
# 10       8/4/2017        Skechers      Amazon Video
# 11       8/4/2017        Skechers  YouTube TrueView
# 12       8/4/2017        Skechers  YouTube TrueView
# 13       8/4/2017        Skechers               NaN
# 14       8/4/2017        Skechers           PreRoll
# 15       8/4/2017        Skechers           PreRoll
# 16       8/4/2017        Skechers           PreRoll
# 17       8/4/2017        Skechers      Amazon Video
# 18       8/4/2017        Skechers      Amazon Video
# 19       8/4/2017        Skechers               NaN
# 20       8/4/2017        Skechers  YouTube TrueView
# 21       8/5/2017        Skechers      Amazon Video
# 22       8/5/2017        Skechers               NaN
# 23       8/5/2017        Skechers               NaN
# 24       8/5/2017        Skechers           PreRoll
# 25       8/5/2017        Skechers  YouTube TrueView
# 26       8/5/2017        Skechers      Amazon Video
# 27       8/5/2017        Skechers               NaN
# 28       8/5/2017        Skechers      Amazon Video
# 29       8/5/2017        Skechers      Amazon Video
# ...           ...             ...               ...
# 18435  12/22/2019  Wrangler Jeans               NaN
# 18436  12/22/2019  Wrangler Jeans               NaN
# 18437  12/22/2019  Wrangler Jeans               NaN
# 18438  12/23/2019  Wrangler Jeans               NaN
# 18439  12/23/2019  Wrangler Jeans               NaN
# 18440  12/23/2019  Wrangler Jeans               NaN
# 18441  12/24/2019  Wrangler Jeans               NaN
# 18442  12/24/2019  Wrangler Jeans               NaN
# 18443  12/24/2019  Wrangler Jeans               NaN
# 18444  12/25/2019  Wrangler Jeans               NaN
# 18445  12/25/2019  Wrangler Jeans               NaN
# 18446  12/25/2019  Wrangler Jeans               NaN
# 18447  12/26/2019  Wrangler Jeans               NaN
# 18448  12/26/2019  Wrangler Jeans               NaN
# 18449  12/26/2019  Wrangler Jeans               NaN
# 18450  12/27/2019  Wrangler Jeans               NaN
# 18451  12/27/2019  Wrangler Jeans               NaN
# 18452  12/27/2019  Wrangler Jeans               NaN
# 18453  12/28/2019  Wrangler Jeans               NaN
# 18454  12/28/2019  Wrangler Jeans               NaN
# 18455  12/28/2019  Wrangler Jeans               NaN
# 18456  12/29/2019  Wrangler Jeans               NaN
# 18457  12/29/2019  Wrangler Jeans               NaN
# 18458  12/29/2019  Wrangler Jeans               NaN
# 18459  12/30/2019  Wrangler Jeans               NaN
# 18460  12/30/2019  Wrangler Jeans               NaN
# 18461  12/30/2019  Wrangler Jeans               NaN
# 18462  12/31/2019  Wrangler Jeans               NaN
# 18463  12/31/2019  Wrangler Jeans               NaN
# 18464  12/31/2019  Wrangler Jeans               NaN
#
#                                        Package Name    Spend Uncapped Spend  \
# 0                 WOMEN_Skechers_Xaxis Connected TV  5554.43        5934.31
# 1                   MEN_Skechers_Xaxis Connected TV  2062.45        2365.28
# 2             YOU BRAND_Skechers_Xaxis Connected TV  8050.20        8411.17
# 3          STREET BRAND_Skechers_Xaxis Connected TV  4633.93        4829.91
# 4        STREET BRAND_Skechers_Xaxis Video Pre-roll    99.38         199.29
# 5          STREET BRAND_Skechers_Xaxis Connected TV  4013.63        4183.38
# 6                         MEN_Skechers_Amazon Video     0.00           0.00
# 7                     MEN_Skechers_YouTube TrueView  1211.16        1211.94
# 8                   MEN_Skechers_Xaxis Connected TV  1781.85        2043.47
# 9                 WOMEN_Skechers_Xaxis Connected TV  4795.22        5123.19
# 10                  YOU BRAND_Skechers_Amazon Video  3934.86        3934.86
# 11           STREET BRAND_Skechers_YouTube TrueView  3988.65        3992.94
# 12                  WOMEN_Skechers_YouTube TrueView  3004.94        3018.28
# 13            YOU BRAND_Skechers_Xaxis Connected TV  6968.27        7280.72
# 14              WOMEN_Skechers_Xaxis Video Pre-roll   473.12         951.29
# 15                MEN_Skechers_Xaxis Video Pre-roll    65.28         130.91
# 16          YOU BRAND_Skechers_Xaxis Video Pre-roll  1096.58        2195.03
# 17               STREET BRAND_Skechers_Amazon Video   690.28         690.28
# 18                      WOMEN_Skechers_Amazon Video     0.00           0.00
# 19                                            Other  2256.87        2256.87
# 20              YOU BRAND_Skechers_YouTube TrueView  4424.45        4591.57
# 21                      WOMEN_Skechers_Amazon Video     0.00           0.00
# 22         STREET BRAND_Skechers_Xaxis Connected TV  4031.40        4201.89
# 23            YOU BRAND_Skechers_Xaxis Connected TV  6973.62        7286.32
# 24              WOMEN_Skechers_Xaxis Video Pre-roll  4216.38        8477.72
# 25           STREET BRAND_Skechers_YouTube TrueView  4544.70        4549.59
# 26                        MEN_Skechers_Amazon Video     0.00           0.00
# 27                WOMEN_Skechers_Xaxis Connected TV  4825.40        5155.43
# 28               STREET BRAND_Skechers_Amazon Video  2219.63        2219.64
# 29                  YOU BRAND_Skechers_Amazon Video  6059.18        6059.18
# ...                                             ...      ...            ...
# 18435  Xaxis Performance Blend Cross Screen Display  1091.20       1108.195
# 18436                            Amazon DSP Display     0.00              0
# 18437                           Display Added Value     0.00              0
# 18438  Xaxis Performance Blend Cross Screen Display   623.14         632.84
# 18439                            Amazon DSP Display     0.00              0
# 18440                           Display Added Value     0.00              0
# 18441  Xaxis Performance Blend Cross Screen Display  1007.73        1023.42
# 18442                            Amazon DSP Display     0.00              0
# 18443                           Display Added Value     0.00              0
# 18444  Xaxis Performance Blend Cross Screen Display  1669.49        1695.49
# 18445                           Display Added Value     0.00              0
# 18446                            Amazon DSP Display     0.00              0
# 18447  Xaxis Performance Blend Cross Screen Display  3271.64        3322.59
# 18448                            Amazon DSP Display     0.00              0
# 18449                           Display Added Value     0.00              0
# 18450  Xaxis Performance Blend Cross Screen Display   864.78         878.25
# 18451                           Display Added Value     0.00              0
# 18452                            Amazon DSP Display     0.00              0
# 18453  Xaxis Performance Blend Cross Screen Display  1270.96       1290.755
# 18454                           Display Added Value     0.00              0
# 18455                            Amazon DSP Display     0.00              0
# 18456  Xaxis Performance Blend Cross Screen Display  1342.68        1363.59
# 18457                           Display Added Value     0.00              0
# 18458                            Amazon DSP Display     0.00              0
# 18459  Xaxis Performance Blend Cross Screen Display   613.52         623.07
# 18460                           Display Added Value     0.00              0
# 18461                            Amazon DSP Display     0.00              0
# 18462  Xaxis Performance Blend Cross Screen Display     4.34          4.405
# 18463                           Display Added Value     0.00              0
# 18464                            Amazon DSP Display     0.00              0
#
#        Margin %  Impressions  Clicks  Video Starts  Video Completes  \
# 0          0.38     126262.0     0.0      126328.0         124447.0
# 1          0.33      50325.0     0.0       50298.0          49593.0
# 2          0.39     178961.0     0.0      179067.0         176140.0
# 3          0.39     102764.0     0.0      102710.0         101170.0
# 4         -0.25      12264.0     3.0        4671.0           6208.0
# 5          0.30      89008.0     0.0       89147.0          88133.0
# 6           NaN          NaN     NaN           NaN              NaN
# 7          0.59      38609.0    40.0           NaN          13466.0
# 8          0.23      43478.0     0.0       43482.0          42986.0
# 9          0.28     109004.0     0.0      108957.0         107838.0
# 10         0.52     221682.0   248.0           NaN         188046.0
# 11         0.58     149319.0   215.0           NaN          44366.0
# 12         0.58      89711.0    99.0           NaN          33425.0
# 13         0.30     154909.0     0.0      154972.0         153111.0
# 14        -0.63      58541.0    11.0       18750.0          32057.0
# 15        -0.43       8056.0     6.0        2898.0           4602.0
# 16        -0.46     135079.0    90.0       54503.0          88892.0
# 17         0.45      38889.0    58.0           NaN          30468.0
# 18          NaN          NaN     NaN           NaN              NaN
# 19         0.00     260571.0   306.0           NaN         218514.0
# 20         0.59     171031.0   240.0           NaN          49213.0
# 21          NaN          NaN     NaN           NaN              NaN
# 22         0.30      89402.0     0.0       89255.0          88296.0
# 23         0.30     155028.0     0.0      155065.0         153030.0
# 24        -0.17     521706.0   221.0      258205.0         300291.0
# 25         0.65     165710.0   280.0           NaN          50551.0
# 26          NaN          NaN     NaN           NaN              NaN
# 27         0.28     109690.0     0.0      109739.0         108421.0
# 28         0.45     125050.0   156.0           NaN         108540.0
# 29         0.50     341362.0   313.0           NaN         312830.0
# ...         ...          ...     ...           ...              ...
# 18435      0.31     221639.0   414.0           NaN              NaN
# 18436       NaN          NaN     NaN           NaN              NaN
# 18437       NaN          NaN     NaN           NaN              NaN
# 18438      0.25     126568.0   266.0           NaN              NaN
# 18439       NaN          NaN     NaN           NaN              NaN
# 18440       NaN          NaN     NaN           NaN              NaN
# 18441     -0.06     204684.0   356.0           NaN              NaN
# 18442       NaN          NaN     NaN           NaN              NaN
# 18443       NaN          NaN     NaN           NaN              NaN
# 18444     -0.02     339098.0   388.0           NaN              NaN
# 18445       NaN          NaN     NaN           NaN              NaN
# 18446       NaN          NaN     NaN           NaN              NaN
# 18447      0.15     664518.0   702.0           NaN              NaN
# 18448       NaN          NaN     NaN           NaN              NaN
# 18449       NaN          NaN     NaN           NaN              NaN
# 18450      0.11     175650.0   226.0           NaN              NaN
# 18451       NaN          NaN     NaN           NaN              NaN
# 18452       NaN          NaN     NaN           NaN              NaN
# 18453      0.28     258151.0   327.0           NaN              NaN
# 18454       NaN          NaN     NaN           NaN              NaN
# 18455       NaN          NaN     NaN           NaN              NaN
# 18456      0.14     272718.0   375.0           NaN              NaN
# 18457       NaN          NaN     NaN           NaN              NaN
# 18458       NaN          NaN     NaN           NaN              NaN
# 18459     -0.01     124614.0   190.0           NaN              NaN
# 18460       NaN          NaN     NaN           NaN              NaN
# 18461       NaN          NaN     NaN           NaN              NaN
# 18462      0.58        881.0     1.0           NaN              NaN
# 18463       NaN          NaN     NaN           NaN              NaN
# 18464       NaN          NaN     NaN           NaN              NaN
#
#       TrueView VTR CTV VCR FB Imps FB Video Starts FB Vid Completes  \
# 0              NaN     NaN     NaN             NaN              NaN
# 1              NaN     NaN     NaN             NaN              NaN
# 2              NaN     NaN     NaN             NaN              NaN
# 3              NaN     NaN     NaN             NaN              NaN
# 4              NaN     NaN     NaN             NaN              NaN
# 5              NaN     NaN     NaN             NaN              NaN
# 6              NaN     NaN     NaN             NaN              NaN
# 7              NaN     NaN     NaN             NaN              NaN
# 8              NaN     NaN     NaN             NaN              NaN
# 9              NaN     NaN     NaN             NaN              NaN
# 10             NaN     NaN     NaN             NaN              NaN
# 11             NaN     NaN     NaN             NaN              NaN
# 12             NaN     NaN     NaN             NaN              NaN
# 13             NaN     NaN     NaN             NaN              NaN
# 14             NaN     NaN     NaN             NaN              NaN
# 15             NaN     NaN     NaN             NaN              NaN
# 16             NaN     NaN     NaN             NaN              NaN
# 17             NaN     NaN     NaN             NaN              NaN
# 18             NaN     NaN     NaN             NaN              NaN
# 19             NaN     NaN     NaN             NaN              NaN
# 20             NaN     NaN     NaN             NaN              NaN
# 21             NaN     NaN     NaN             NaN              NaN
# 22             NaN     NaN     NaN             NaN              NaN
# 23             NaN     NaN     NaN             NaN              NaN
# 24             NaN     NaN     NaN             NaN              NaN
# 25             NaN     NaN     NaN             NaN              NaN
# 26             NaN     NaN     NaN             NaN              NaN
# 27             NaN     NaN     NaN             NaN              NaN
# 28             NaN     NaN     NaN             NaN              NaN
# 29             NaN     NaN     NaN             NaN              NaN
# ...            ...     ...     ...             ...              ...
# 18435          NaN     NaN     NaN             NaN              NaN
# 18436          NaN     NaN     NaN             NaN              NaN
# 18437          NaN     NaN     NaN             NaN              NaN
# 18438          NaN     NaN     NaN             NaN              NaN
# 18439          NaN     NaN     NaN             NaN              NaN
# 18440          NaN     NaN     NaN             NaN              NaN
# 18441          NaN     NaN     NaN             NaN              NaN
# 18442          NaN     NaN     NaN             NaN              NaN
# 18443          NaN     NaN     NaN             NaN              NaN
# 18444          NaN     NaN     NaN             NaN              NaN
# 18445          NaN     NaN     NaN             NaN              NaN
# 18446          NaN     NaN     NaN             NaN              NaN
# 18447          NaN     NaN     NaN             NaN              NaN
# 18448          NaN     NaN     NaN             NaN              NaN
# 18449          NaN     NaN     NaN             NaN              NaN
# 18450          NaN     NaN     NaN             NaN              NaN
# 18451          NaN     NaN     NaN             NaN              NaN
# 18452          NaN     NaN     NaN             NaN              NaN
# 18453          NaN     NaN     NaN             NaN              NaN
# 18454          NaN     NaN     NaN             NaN              NaN
# 18455          NaN     NaN     NaN             NaN              NaN
# 18456          NaN     NaN     NaN             NaN              NaN
# 18457          NaN     NaN     NaN             NaN              NaN
# 18458          NaN     NaN     NaN             NaN              NaN
# 18459          NaN     NaN     NaN             NaN              NaN
# 18460          NaN     NaN     NaN             NaN              NaN
# 18461          NaN     NaN     NaN             NaN              NaN
# 18462          NaN     NaN     NaN             NaN              NaN
# 18463          NaN     NaN     NaN             NaN              NaN
# 18464          NaN     NaN     NaN             NaN              NaN
#
#       Total Conversions
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# ...                 ...
# 18435               NaN
# 18436               NaN
# 18437               NaN
# 18438               NaN
# 18439               NaN
# 18440               NaN
# 18441               NaN
# 18442               NaN
# 18443               NaN
# 18444               NaN
# 18445               NaN
# 18446               NaN
# 18447               NaN
# 18448               NaN
# 18449               NaN
# 18450               NaN
# 18451               NaN
# 18452               NaN
# 18453               NaN
# 18454               NaN
# 18455               NaN
# 18456               NaN
# 18457               NaN
# 18458               NaN
# 18459               NaN
# 18460               NaN
# 18461               NaN
# 18462               NaN
# 18463               NaN
# 18464               NaN
#
# [18465 rows x 17 columns]

# %%
#Checking data types and number of nulls for full dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18465 entries, 0 to 18464
# Data columns (total 17 columns):
# Day                  18465 non-null object
# Advertiser           18465 non-null object
# Tactic               9849 non-null object
# Package Name         18465 non-null object
# Spend                18465 non-null float64
# Uncapped Spend       18323 non-null object
# Margin %             13318 non-null float64
# Impressions          14593 non-null float64
# Clicks               14590 non-null float64
# Video Starts         9024 non-null float64
# Video Completes      11437 non-null float64
# TrueView VTR         649 non-null object
# CTV VCR              362 non-null object
# FB Imps              389 non-null object
# FB Video Starts      389 non-null object
# FB Vid Completes     389 non-null object
# Total Conversions    543 non-null object
# dtypes: float64(6), object(11)
# memory usage: 2.4+ MB

# %%
#Finding missing values for Impressions
df["Impressions"].isnull().sum()
# Out:
# 3872

# %%
#Checking dataframe shape
df.shape
# Out:
# (18465, 17)

# %%
#removing missing values from impressions column and creating new dataframe
df_imps_cleaned = df[df["Impressions"].notnull()]

# %%
#Checking shape of cleaned dataframe
df_imps_cleaned.shape
# Out:
# (14593, 17)

# %%
#checking data types of new dataframe
df_imps_cleaned.dtypes
# Out:
# Day                   object
# Advertiser            object
# Tactic                object
# Package Name          object
# Spend                float64
# Uncapped Spend        object
# Margin %             float64
# Impressions          float64
# Clicks               float64
# Video Starts         float64
# Video Completes      float64
# TrueView VTR          object
# CTV VCR               object
# FB Imps               object
# FB Video Starts       object
# FB Vid Completes      object
# Total Conversions     object
# dtype: object

# %%
#inspecting date column
df_imps_cleaned["Day"].head()
# Out:
# 0    8/3/2017
# 1    8/3/2017
# 2    8/3/2017
# 3    8/3/2017
# 4    8/4/2017
# Name: Day, dtype: object

# %%
#Updating date field to pandas datetime
df_imps_cleaned["Day"] = pd.to_datetime(df_imps_cleaned["Day"])
df_imps_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14593 entries, 0 to 18462
# Data columns (total 17 columns):
# Day                  14593 non-null datetime64[ns]
# Advertiser           14593 non-null object
# Tactic               7933 non-null object
# Package Name         14593 non-null object
# Spend                14593 non-null float64
# Uncapped Spend       14491 non-null object
# Margin %             13318 non-null float64
# Impressions          14593 non-null float64
# Clicks               14590 non-null float64
# Video Starts         9024 non-null float64
# Video Completes      11437 non-null float64
# TrueView VTR         649 non-null object
# CTV VCR              362 non-null object
# FB Imps              389 non-null object
# FB Video Starts      389 non-null object
# FB Vid Completes     389 non-null object
# Total Conversions    521 non-null object
# dtypes: datetime64[ns](1), float64(6), object(10)
# memory usage: 2.0+ MB
# /home/nyros/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#Pivoting total impressions by day
imps_pivot = pd.pivot_table(df_imps_cleaned, values="Impressions", index="Day", aggfunc=np.sum).reset_index()
imps_pivot.head()
# Out:
#          Day  Impressions
# 0 2017-08-03     458312.0
# 1 2017-08-04    1580151.0
# 2 2017-08-05    3713114.0
# 3 2017-08-06    4266741.0
# 4 2017-08-07    4291094.0

# %%
#Updating printing options for whole numbers and decimals
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
imps_pivot.describe()
# Out:
#        Impressions
# count      864.000
# mean   3286194.498
# std    3144276.970
# min          0.000
# 25%    1230775.750
# 50%    2304911.000
# 75%    4007025.000
# max   18750050.000

# %%
#Line plot for total impressions by day
fig, ax = plt.subplots(figsize=(16, 10)) 
g = sns.lineplot(ax=ax, data=imps_pivot, x='Day', y='Impressions')
plt.ylabel('Impressions')
plt.ticklabel_format(style='plain', axis='y')
plt.title('Total Impressions for Retail Direct Accounts')
plt.show()
# Out:
# /home/nyros/anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
#Pivoting total impressions by day and advertiser
imps_advertiser_pivot = pd.pivot_table(df_imps_cleaned, values="Impressions", index=["Day", "Advertiser"], 
                                      aggfunc=np.sum).reset_index()
imps_advertiser_pivot.head()
# Out:
#          Day Advertiser  Impressions
# 0 2017-08-03   Skechers   458312.000
# 1 2017-08-04   Skechers  1580151.000
# 2 2017-08-05   Skechers  3713114.000
# 3 2017-08-06   Skechers  4266741.000
# 4 2017-08-07   Skechers  4291094.000

# %%
#Line Plot impressions by by advertiser
fig, ax = plt.subplots(figsize=(16, 10))
g = sns.lineplot(ax=ax, data=imps_advertiser_pivot, x="Day", y="Impressions", hue="Advertiser")
plt.ticklabel_format(style="plain", axis="y")
plt.ylabel("Impressions")
plt.title("Total Impressions for Retail Direct Accounts by Account")
plt.show()

# %%
#Cleaning the dataframe to remove rows with null clicks, inspecting dataframe
df_clicks_cleaned = df_imps_cleaned[df_imps_cleaned["Clicks"].notnull()]
df_clicks_cleaned.head()
# Out:
#          Day Advertiser   Tactic                                Package Name  \
# 0 2017-08-03   Skechers      NaN           WOMEN_Skechers_Xaxis Connected TV
# 1 2017-08-03   Skechers      NaN             MEN_Skechers_Xaxis Connected TV
# 2 2017-08-03   Skechers      NaN       YOU BRAND_Skechers_Xaxis Connected TV
# 3 2017-08-03   Skechers      NaN    STREET BRAND_Skechers_Xaxis Connected TV
# 4 2017-08-04   Skechers  PreRoll  STREET BRAND_Skechers_Xaxis Video Pre-roll
#
#      Spend Uncapped Spend  Margin %  Impressions  Clicks  Video Starts  \
# 0 5554.430        5934.31     0.380   126262.000   0.000    126328.000
# 1 2062.450        2365.28     0.330    50325.000   0.000     50298.000
# 2 8050.200        8411.17     0.390   178961.000   0.000    179067.000
# 3 4633.930        4829.91     0.390   102764.000   0.000    102710.000
# 4   99.380         199.29    -0.250    12264.000   3.000      4671.000
#
#    Video Completes TrueView VTR CTV VCR FB Imps FB Video Starts  \
# 0       124447.000          NaN     NaN     NaN             NaN
# 1        49593.000          NaN     NaN     NaN             NaN
# 2       176140.000          NaN     NaN     NaN             NaN
# 3       101170.000          NaN     NaN     NaN             NaN
# 4         6208.000          NaN     NaN     NaN             NaN
#
#   FB Vid Completes Total Conversions
# 0              NaN               NaN
# 1              NaN               NaN
# 2              NaN               NaN
# 3              NaN               NaN
# 4              NaN               NaN

# %%
#clicks by day by advertiser pivot
clicks_advertiser_pivot = pd.pivot_table(df_clicks_cleaned, values=["Impressions", "Clicks"], index=["Day", "Advertiser"], 
                                      aggfunc=np.sum).reset_index()
clicks_advertiser_pivot
# Out:
#             Day      Advertiser    Clicks  Impressions
# 0    2017-08-03        Skechers     0.000   458312.000
# 1    2017-08-04        Skechers  1316.000  1580151.000
# 2    2017-08-05        Skechers  2536.000  3713114.000
# 3    2017-08-06        Skechers  2237.000  4266741.000
# 4    2017-08-07        Skechers  2197.000  4291094.000
# 5    2017-08-08        Skechers  2325.000  4854977.000
# 6    2017-08-09        Skechers  2629.000  5305955.000
# 7    2017-08-10        Skechers  6715.000  7494257.000
# 8    2017-08-11        Skechers 10531.000  8321200.000
# 9    2017-08-12        Skechers 11392.000  8021897.000
# 10   2017-08-13        Skechers 11171.000  8193672.000
# 11   2017-08-14        Skechers 10593.000  8438633.000
# 12   2017-08-15        Skechers  9675.000  8214606.000
# 13   2017-08-16        Skechers  8351.000  7522140.000
# 14   2017-08-17        Skechers  7602.000  6909578.000
# 15   2017-08-18        Skechers  6571.000  7029854.000
# 16   2017-08-19        Skechers  7121.000  7032427.000
# 17   2017-08-20        Skechers  8379.000  6720859.000
# 18   2017-08-21        Skechers  8196.000  5762204.000
# 19   2017-08-22        Skechers  6363.000  4682395.000
# 20   2017-08-23        Skechers  6298.000  4073345.000
# 21   2017-08-24        Skechers  6226.000  4028356.000
# 22   2017-08-25        Skechers  6048.000  3582031.000
# 23   2017-08-26        Skechers  6737.000  3512547.000
# 24   2017-08-27        Skechers  7657.000  4177614.000
# 25   2017-08-28        Skechers  7046.000  4058405.000
# 26   2017-08-29        Skechers  8266.000  4028230.000
# 27   2017-08-30        Skechers 10833.000  4023969.000
# 28   2017-08-31        Skechers 12771.000  3918790.000
# 29   2017-09-01        Skechers 17027.000  5272080.000
# ...         ...             ...       ...          ...
# 2094 2019-12-17    David Yurman  8311.000  7820090.000
# 2095 2019-12-17  Wrangler Jeans   227.000   129969.000
# 2096 2019-12-18    David Yurman  7277.000  6059935.000
# 2097 2019-12-18  Wrangler Jeans   240.000   130454.000
# 2098 2019-12-19    David Yurman  5726.000  4601658.000
# 2099 2019-12-19  Wrangler Jeans   189.000   106411.000
# 2100 2019-12-20    David Yurman  5362.000  4421950.000
# 2101 2019-12-20  Wrangler Jeans   339.000   173153.000
# 2102 2019-12-21    David Yurman  5102.000  4531289.000
# 2103 2019-12-21  Wrangler Jeans   305.000   172680.000
# 2104 2019-12-22    David Yurman  5293.000  4422891.000
# 2105 2019-12-22  Wrangler Jeans   414.000   221639.000
# 2106 2019-12-23    David Yurman  3624.000  3861969.000
# 2107 2019-12-23  Wrangler Jeans   266.000   126568.000
# 2108 2019-12-24    David Yurman  3553.000  2975599.000
# 2109 2019-12-24  Wrangler Jeans   356.000   204684.000
# 2110 2019-12-25    David Yurman  3557.000  2921572.000
# 2111 2019-12-25  Wrangler Jeans   388.000   339098.000
# 2112 2019-12-26    David Yurman  2938.000  2747251.000
# 2113 2019-12-26  Wrangler Jeans   702.000   664518.000
# 2114 2019-12-27    David Yurman  1922.000  1519134.000
# 2115 2019-12-27  Wrangler Jeans   226.000   175650.000
# 2116 2019-12-28    David Yurman  2787.000  1837495.000
# 2117 2019-12-28  Wrangler Jeans   327.000   258151.000
# 2118 2019-12-29    David Yurman  2287.000  1398804.000
# 2119 2019-12-29  Wrangler Jeans   375.000   272718.000
# 2120 2019-12-30    David Yurman  1791.000  1478361.000
# 2121 2019-12-30  Wrangler Jeans   190.000   124614.000
# 2122 2019-12-31    David Yurman  1492.000  1213135.000
# 2123 2019-12-31  Wrangler Jeans     1.000      881.000
#
# [2124 rows x 4 columns]

# %%
#Creating CTR column
clicks_advertiser_pivot["CTR"] = (clicks_advertiser_pivot["Clicks"] / clicks_advertiser_pivot["Impressions"]) * 100
clicks_advertiser_pivot.head()
# Out:
#          Day Advertiser   Clicks  Impressions   CTR
# 0 2017-08-03   Skechers    0.000   458312.000 0.000
# 1 2017-08-04   Skechers 1316.000  1580151.000 0.083
# 2 2017-08-05   Skechers 2536.000  3713114.000 0.068
# 3 2017-08-06   Skechers 2237.000  4266741.000 0.052
# 4 2017-08-07   Skechers 2197.000  4291094.000 0.051

# %%
#Total Clicks by day pivot
clicks_pivot = pd.pivot_table(df_clicks_cleaned, values=["Impressions", "Clicks"], index=["Day"], 
                                      aggfunc=np.sum).reset_index()
clicks_pivot.head()
# Out:
#          Day   Clicks  Impressions
# 0 2017-08-03    0.000   458312.000
# 1 2017-08-04 1316.000  1580151.000
# 2 2017-08-05 2536.000  3713114.000
# 3 2017-08-06 2237.000  4266741.000
# 4 2017-08-07 2197.000  4291094.000

# %%
#Creating CTR column
clicks_pivot["CTR"] = (clicks_pivot["Clicks"] / clicks_pivot["Impressions"]) * 100
clicks_pivot.head()
# Out:
#          Day   Clicks  Impressions   CTR
# 0 2017-08-03    0.000   458312.000 0.000
# 1 2017-08-04 1316.000  1580151.000 0.083
# 2 2017-08-05 2536.000  3713114.000 0.068
# 3 2017-08-06 2237.000  4266741.000 0.052
# 4 2017-08-07 2197.000  4291094.000 0.051

# %%
#Line Plot overaall CTR
fig, ax = plt.subplots(figsize=(16, 10))
g = sns.lineplot(ax=ax, data=clicks_pivot, x="Day", y="CTR")
plt.ticklabel_format(style="plain", axis="y")
plt.ylabel("CTR %")
plt.title("CTR for Retail Direct Accounts by Account")
#plt.show()
# Out:
# Text(0.5, 1.0, 'CTR for Retail Direct Accounts by Account')

# %%
#descriptive stats for clicks by advertiser
clicks_advertiser_pivot.describe()
# Out:
#          Clicks  Impressions      CTR
# count  2124.000     2124.000 2100.000
# mean   1870.052  1336615.875    0.329
# std    2976.968  2074971.637    5.724
# min       0.000        0.000    0.000
# 25%     158.000   130446.750    0.086
# 50%     799.000   522745.500    0.116
# 75%    2097.250  1589689.250    0.180
# max   25820.000 15295038.000  250.000

# %%
#Removing rows where CTR is above 10 
clicks_advertiser_pivot = clicks_advertiser_pivot[clicks_advertiser_pivot["CTR"] < 10]

# %%
#Line Plot CTR by advertiser
fig, ax = plt.subplots(figsize=(16, 10))
g = sns.lineplot(ax=ax, data=clicks_advertiser_pivot, x="Day", y="CTR", hue="Advertiser")
plt.ticklabel_format(style="plain", axis="y")
plt.ylabel("CTR %")
plt.title("CTR for Retail Direct Accounts by Account")
plt.show()

# %%
df_clicks_cleaned.head()
# Out:
#          Day Advertiser   Tactic                                Package Name  \
# 0 2017-08-03   Skechers      NaN           WOMEN_Skechers_Xaxis Connected TV
# 1 2017-08-03   Skechers      NaN             MEN_Skechers_Xaxis Connected TV
# 2 2017-08-03   Skechers      NaN       YOU BRAND_Skechers_Xaxis Connected TV
# 3 2017-08-03   Skechers      NaN    STREET BRAND_Skechers_Xaxis Connected TV
# 4 2017-08-04   Skechers  PreRoll  STREET BRAND_Skechers_Xaxis Video Pre-roll
#
#      Spend Uncapped Spend  Margin %  Impressions  Clicks  Video Starts  \
# 0 5554.430        5934.31     0.380   126262.000   0.000    126328.000
# 1 2062.450        2365.28     0.330    50325.000   0.000     50298.000
# 2 8050.200        8411.17     0.390   178961.000   0.000    179067.000
# 3 4633.930        4829.91     0.390   102764.000   0.000    102710.000
# 4   99.380         199.29    -0.250    12264.000   3.000      4671.000
#
#    Video Completes TrueView VTR CTV VCR FB Imps FB Video Starts  \
# 0       124447.000          NaN     NaN     NaN             NaN
# 1        49593.000          NaN     NaN     NaN             NaN
# 2       176140.000          NaN     NaN     NaN             NaN
# 3       101170.000          NaN     NaN     NaN             NaN
# 4         6208.000          NaN     NaN     NaN             NaN
#
#   FB Vid Completes Total Conversions
# 0              NaN               NaN
# 1              NaN               NaN
# 2              NaN               NaN
# 3              NaN               NaN
# 4              NaN               NaN

# %%
#Adding Year and Month to the dataframe
df_clicks_cleaned["Day"] = pd.to_datetime(df_clicks_cleaned["Day"], errors='coerce')
df_clicks_cleaned["Month"] = df_clicks_cleaned["Day"].dt.month
df_clicks_cleaned["Year"] = df_clicks_cleaned["Day"].dt.year
# Out:
# /home/nyros/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/nyros/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/nyros/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df_clicks_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14590 entries, 0 to 18462
# Data columns (total 19 columns):
# Day                  14590 non-null datetime64[ns]
# Advertiser           14590 non-null object
# Tactic               7930 non-null object
# Package Name         14590 non-null object
# Spend                14590 non-null float64
# Uncapped Spend       14488 non-null object
# Margin %             13315 non-null float64
# Impressions          14590 non-null float64
# Clicks               14590 non-null float64
# Video Starts         9024 non-null float64
# Video Completes      11437 non-null float64
# TrueView VTR         649 non-null object
# CTV VCR              362 non-null object
# FB Imps              389 non-null object
# FB Video Starts      389 non-null object
# FB Vid Completes     389 non-null object
# Total Conversions    521 non-null object
# Month                14590 non-null int64
# Year                 14590 non-null int64
# dtypes: datetime64[ns](1), float64(6), int64(2), object(10)
# memory usage: 2.2+ MB

# %%
df_clicks_cleaned.head()
# Out:
#          Day Advertiser   Tactic                                Package Name  \
# 0 2017-08-03   Skechers      NaN           WOMEN_Skechers_Xaxis Connected TV
# 1 2017-08-03   Skechers      NaN             MEN_Skechers_Xaxis Connected TV
# 2 2017-08-03   Skechers      NaN       YOU BRAND_Skechers_Xaxis Connected TV
# 3 2017-08-03   Skechers      NaN    STREET BRAND_Skechers_Xaxis Connected TV
# 4 2017-08-04   Skechers  PreRoll  STREET BRAND_Skechers_Xaxis Video Pre-roll
#
#      Spend Uncapped Spend  Margin %  Impressions  Clicks  Video Starts  \
# 0 5554.430        5934.31     0.380   126262.000   0.000    126328.000
# 1 2062.450        2365.28     0.330    50325.000   0.000     50298.000
# 2 8050.200        8411.17     0.390   178961.000   0.000    179067.000
# 3 4633.930        4829.91     0.390   102764.000   0.000    102710.000
# 4   99.380         199.29    -0.250    12264.000   3.000      4671.000
#
#    Video Completes TrueView VTR CTV VCR FB Imps FB Video Starts  \
# 0       124447.000          NaN     NaN     NaN             NaN
# 1        49593.000          NaN     NaN     NaN             NaN
# 2       176140.000          NaN     NaN     NaN             NaN
# 3       101170.000          NaN     NaN     NaN             NaN
# 4         6208.000          NaN     NaN     NaN             NaN
#
#   FB Vid Completes Total Conversions  Month  Year
# 0              NaN               NaN      8  2017
# 1              NaN               NaN      8  2017
# 2              NaN               NaN      8  2017
# 3              NaN               NaN      8  2017
# 4              NaN               NaN      8  2017

# %%
#Pivoting overall clicks by year
clicks_year_pivot = pd.pivot_table(df_clicks_cleaned, values=["Impressions", "Clicks"], index=["Year"], 
                                      aggfunc=np.sum).reset_index()
clicks_year_pivot.head()
# Out:
#    Year      Clicks    Impressions
# 0  2017  616986.000  334174450.000
# 1  2018 1239274.000  940195259.000
# 2  2019 2115731.000 1564602410.000

# %%
#Creating CTR column
clicks_year_pivot["CTR"] = (clicks_year_pivot["Clicks"] / clicks_year_pivot["Impressions"]) * 100
clicks_year_pivot.head()
# Out:
#    Year      Clicks    Impressions   CTR
# 0  2017  616986.000  334174450.000 0.185
# 1  2018 1239274.000  940195259.000 0.132
# 2  2019 2115731.000 1564602410.000 0.135

# %%
#Bar Plot for YoY CTR
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(16, 10))
ax = sns.barplot(x="Year", y="CTR", data=clicks_year_pivot)

# %%
#Month-Yearcombo column
df_clicks_cleaned["MonthYear"] = df_clicks_cleaned["Day"].dt.strftime('%Y-%m')
df_clicks_cleaned.head()
# Out:
# /home/nyros/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#          Day Advertiser   Tactic                                Package Name  \
# 0 2017-08-03   Skechers      NaN           WOMEN_Skechers_Xaxis Connected TV
# 1 2017-08-03   Skechers      NaN             MEN_Skechers_Xaxis Connected TV
# 2 2017-08-03   Skechers      NaN       YOU BRAND_Skechers_Xaxis Connected TV
# 3 2017-08-03   Skechers      NaN    STREET BRAND_Skechers_Xaxis Connected TV
# 4 2017-08-04   Skechers  PreRoll  STREET BRAND_Skechers_Xaxis Video Pre-roll
#
#      Spend Uncapped Spend  Margin %  Impressions  Clicks  Video Starts  \
# 0 5554.430        5934.31     0.380   126262.000   0.000    126328.000
# 1 2062.450        2365.28     0.330    50325.000   0.000     50298.000
# 2 8050.200        8411.17     0.390   178961.000   0.000    179067.000
# 3 4633.930        4829.91     0.390   102764.000   0.000    102710.000
# 4   99.380         199.29    -0.250    12264.000   3.000      4671.000
#
#    Video Completes TrueView VTR CTV VCR FB Imps FB Video Starts  \
# 0       124447.000          NaN     NaN     NaN             NaN
# 1        49593.000          NaN     NaN     NaN             NaN
# 2       176140.000          NaN     NaN     NaN             NaN
# 3       101170.000          NaN     NaN     NaN             NaN
# 4         6208.000          NaN     NaN     NaN             NaN
#
#   FB Vid Completes Total Conversions  Month  Year MonthYear
# 0              NaN               NaN      8  2017   2017-08
# 1              NaN               NaN      8  2017   2017-08
# 2              NaN               NaN      8  2017   2017-08
# 3              NaN               NaN      8  2017   2017-08
# 4              NaN               NaN      8  2017   2017-08

# %%
#Aggregating by Month
clicks_month_pivot = pd.pivot_table(df_clicks_cleaned, values=["Impressions", "Clicks"], index=["MonthYear"], 
                                      aggfunc=np.sum).reset_index()
clicks_month_pivot.head()
# Out:
#   MonthYear     Clicks   Impressions
# 0   2017-08 197782.000 154217353.000
# 1   2017-09  60634.000  28619291.000
# 2   2017-10  69485.000  32162253.000
# 3   2017-11  95283.000  57761336.000
# 4   2017-12 193802.000  61414217.000

# %%
clicks_month_pivot["CTR"] = (clicks_month_pivot["Clicks"] / clicks_month_pivot["Impressions"]) * 100
clicks_month_pivot.head()
# Out:
#   MonthYear     Clicks   Impressions   CTR
# 0   2017-08 197782.000 154217353.000 0.128
# 1   2017-09  60634.000  28619291.000 0.212
# 2   2017-10  69485.000  32162253.000 0.216
# 3   2017-11  95283.000  57761336.000 0.165
# 4   2017-12 193802.000  61414217.000 0.316

# %%
#Line Plot overaall CTR
fig, ax = plt.subplots(figsize=(16, 10))
g = sns.lineplot(ax=ax, data=clicks_month_pivot, x="MonthYear", y="CTR")
plt.ticklabel_format(style="plain", axis="y")
plt.xticks(rotation=45)
plt.ylabel("CTR %")
plt.title("CTR for Retail Direct Accounts Month over Month")
plt.show()

# %%
import statsmodels.api as sm 
import matplotlib.pyplot as plt
from pylab import rcParams

# %%
rcParams['figure.figsize']= 11, 9 
decomposition=sm.tsa.seasonal_decompose(clicks_pivot['Clicks'], freq=30)
fig=decomposition.plot()
plt.show()
# Out:
# /home/nyros/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: the 'freq' keyword is deprecated, use 'period' instead

# %%
decomp_seasonal=decomposition.seasonal
ax=decomp_seasonal.plot(figsize=(14,2))
ax.set_xlabel('Date')
ax.set_ylabel('seasonality of time series')
ax.set_title('seasonality')
# Out:
# Text(0.5, 1.0, 'seasonality')

# %%
rcParams['figure.figsize']= 11, 9 
decomposition=sm.tsa.seasonal_decompose(clicks_pivot['Impressions'], freq=30)
fig=decomposition.plot()
plt.show()
# Out:
# /home/nyros/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: the 'freq' keyword is deprecated, use 'period' instead

# %%
import pandas as pd
from pandas.plotting import scatter_matrix
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

#Plot hist from numerical variables
clicks_pivot.hist(bins=50, figsize=(20,15))
plt.show()

#make a matrix correlation for each variable numeric in your df
corr_matrix = clicks_pivot.corr()

#Make boxplot to get outliers
sns.set_style("whitegrid")
ax = sns.boxplot(x="Day", y="Clicks", data=clicks_pivot, palette="Set3")
